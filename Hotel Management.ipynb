# %%
from pprint import pprint
import time
import webbrowser

# %%
print("\n\t WELCOME TO SARAVANA BHAVAN")
print(" \t***************")
print(" \tBOTH VEG AND NON-VEG RESTRARENT")
# Out:
# 	 WELCOME TO SARAVANA BHAVAN
#  	***************
#  	BOTH VEG AND NON-VEG RESTRARENT

# %%
command = ""
bill = 0
order = []
eat = False

# %%
# HELP
print("""
  website-To show official website
  order online-To order our products through online mode
  menu card-To show menu card of both veg and non-veg
  quit-To end
  bill-To get total cost
  cash-To pay bill amount using cash
  online pay-To pay bill amount using online transaction
  """)
# Out:
#   website-To show official website
#   order online-To order our products through online mode
#   menu card-To show menu card of both veg and non-veg
#   quit-To end
#   bill-To get total cost
#   cash-To pay bill amount using cash
#   online pay-To pay bill amount using online transaction

# %%
# MENU CARD
print("""
 \t VEG
  1-Idily
  2-Dosa
  3-Veg-fried rice
  4-Sambar rice
  5-Curd rice
  6-Vadai """)
print("""
 \t NON-VEG
  7-Chicken Biriyani
  8-Mutton Biriyani
  9-Chicken Fried Rice
  10-prawn Fried Rice
  11-Fish Fry
  12-Chicken Roll""")
# Out:
#  	 VEG
#   1-Idily
#   2-Dosa
#   3-Veg-fried rice
#   4-Sambar rice
#   5-Curd rice
#   6-Vadai
#
#  	 NON-VEG
#   7-Chicken Biriyani
#   8-Mutton Biriyani
#   9-Chicken Fried Rice
#   10-prawn Fried Rice
#   11-Fish Fry
#   12-Chicken Roll

# %%
# WEBSITE
import time
import webbrowser
time.sleep(2)
print("opening website,please wait")
webbrowser.open("https://saravanabhavan.com")
# Out:
# opening website,please wait
# True

# %%
from pprint import pprint
import time
import webbrowser
print("\n\t WELCOME TO SARAVANA BHAVAN")
print(" \t***************")
print(" \tBOTH VEG AND NON-VEG RESTRARENT")


command = ""
bill = 0
order = []
eat = False

while True:
    command = input("Enter your choice: ")

    if command == "menu card":

        print("""
 \t VEG
  1-Idily
  2-Dosa
  3-Veg-fried rice
  4-Sambar rice
  5-Curd rice
  6-Vadai """)
        print("""
 \t NON-VEG
  7-Chicken Biriyani
  8-Mutton Biriyani
  9-Chicken Fried Rice
  10-prawn Fried Rice
  11-Fish Fry
  12-Chicken Roll""")

    elif command == "help":
        print("""
  website-To show official website
  order online-To order our products through online mode
  menu card-To show menu card of both veg and non-veg
  quit-To end
  bill-To get total cost
  cash-To pay bill amount using cash
  online pay-To pay bill amount using online transaction
  """)
    elif command == "website":
        time.sleep(2)
        print("opening website,please wait")
        webbrowser.open("https://saravanabhavan.com")

    elif command == "1":
        print("Idily")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Idily")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Idily")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"idily- {quantity} - RS {20*quantity}")
        bill += 20*quantity
        eat = True

    elif command == "2":
        print("Dosa")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Dosa")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Dosa")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"dosa- {quantity} - RS {25*quantity}")
        bill += 25*quantity
        eat = True

    elif command == "3":
        print("Veg fried-rice")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Veg-fried rice")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Veg-fried rice")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Veg-fried rice- {quantity} - {50*quantity} ")
        bill += 50*quantity
        eat = True

    elif command == "4":
        print("Sambar rice")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Sambar rice")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Sambar rice")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"sambar rice- {quantity} - RS {45*quantity}")
        bill += 45*quantity
        eat = True

    elif command == "5":
        print("Curd rice")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Curd rice")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Curd rice")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Curd rice- {quantity} - RS {35*quantity}")
        bill += 35*quantity
        eat = True

    elif command == "6":
        print("Vadai")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Vadai")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Vadai")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Vadai- {quantity} - RS {10*quantity}")
        bill += 10*quantity
        eat = True

    elif command == "7":
        print("Chicken biriyani")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Chicken biriyani")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for chicken biriyani")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Chicken biriyani- {quantity} - RS {200*quantity}")
        bill += 200*quantity
        eat = True

    elif command == "8":
        print("Mutton biriyani")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Mutton biriyani")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Mutton biriyani")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Mutton biriyani- {quantity} - RS {300*quantity}")
        bill += 300*quantity
        eat = True

    elif command == "9":
        print("Chicken fried-rice")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Chicken fried-rice")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for chicken fried-rice")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Chicken fried-rice- {quantity} - RS {80*quantity}")
        bill += 80*quantity
        eat = True

    elif command == "10":
        print("Prawn fried-rice")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity}  prawn fried-rice ")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for prawn fried-rice")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"prawn fried-rice- {quantity} - RS {150*quantity}")
        bill += 150*quantity
        eat = True

    elif command == "11":
        print("Fish fry")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity} Fish fry")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Fish fry")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Fish fry- {quantity} -RS {35*quantity}")
        bill += 35*quantity
        eat = True
    elif command == "12":
        print("Chicken roll")
        quantity = int(input("How many: "))
        time.sleep(1)
        print(f"You ordered {quantity}  Chicken roll")
        time.sleep(2)
        print("your order confirmed")
        time.sleep(2)
        print("Please wait 5 seconds for Chicken roll")
        time.sleep(2)
        print("Your order came,Enjoy it")
        order.append(f"Chicken roll- {quantity} - RS {49*quantity}")
        bill += 49*quantity
        eat = True
    elif command == "quit":
        break
    elif command == "order online":
        webbrowser.open("https://saravanabhavan.com")
    elif command == "bill":
        if eat == True:
            for dinesh in order:
                print(dinesh)
        else:
            print("Choose items first")
            break
        print(f"Total = RS {bill}")
        time.sleep(2)
        print("CASH or ONLINE PAY")
    elif command == "cash":
        print(f"Total = RS {bill}")
        amount = int(input("Enter the amount given by the customer : "))
        amount -= bill
        time.sleep(2)
        print(f'Amount  returned to the customer = RS {amount}')
        time.sleep(3)
        print("Thank you")
        time.sleep(1)
        print('Visit again')
        time.sleep(1)
        break

    elif command == "online pay":
        if eat == True:
            for dinesh in order:
                print(dinesh)
        else:
            print("Choose items first")
            break
        print("pls enter the UPI ID given below for online pay")
        time.sleep(2)
        print("UPI ID: 1234567")
        time.sleep(3)
        print(f"{bill} paid successful")
        time.sleep(2)
        print("Thank you")
        time.sleep(2)
        print('Visit again')
        time.sleep(1)
        print("Please enter the OTP correctly")
        break
# Out:
# 	 WELCOME TO SARAVANA BHAVAN
#  	***************
#  	BOTH VEG AND NON-VEG RESTRARENT
# Enter your choice: 1
# Idily
# How many: 3
# You ordered 3 Idily
# your order confirmed
# Please wait 5 seconds for Idily
# Your order came,Enjoy it
# Enter your choice: 6
# Vadai
# How many: 3
# You ordered 3 Vadai
# your order confirmed
# Please wait 5 seconds for Vadai
# Your order came,Enjoy it
# Enter your choice: bill
# idily- 3 - RS 60
# Vadai- 3 - RS 30
# Total = RS 90
# CASH or ONLINE PAY
# Enter your choice: cash
# Total = RS 90
# Enter the amount given by the customer : 100
# Amount  returned to the customer = RS 10
# Thank you
# Visit again
